# %%
print("python")
# Out:
# python

# %%
total=0
number=5

while number <=1:
   total=number * total

# %%
n=12345
temp=0
while n>0:
    rem=n%10
    temp=temp*10+rem
    n=n//10
print(temp)
# Out:
# 54321

# %%
number=12345
temp=number

while number<0:
    print(temp)
    number+=temp
    print(number)

# %%
with open("shopping.txt",'w') as f:
    f.write="vanmugelan/n" \
    "how are you/n" \
    "what fruits u want/n" \
    "i need apple , orange"
    f.write

# %%
with open("shopping.txt","r")as f:
    fruits=f.read()
    print(fruits)
